# %% [markdown]
# ---
# title: Table of contents
# jupyter:
#   jupytext:
#     text_representation:
#       extension: .qmd
#       format_name: quarto
#       format_version: '1.0'
#       jupytext_version: 1.16.2
#   kernelspec:
#     display_name: Python 3 (ipykernel)
#     language: python
#     name: python3
# ---
#
# Exploration of whether folium can be used for all my use cases?
# 1. [OneMap API calls](#OneMap)
# 1. [Routes](#Routes)
# 1. [Regions](#Regions)
# 1. [Spatial Query](#SpatialQuery)
#
# ### Things to think about
# 1. Collect more layers that allow interactions across different amenities
# 1. Establishing of walking routes from home to different amenities

# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import os
import time
import folium
import polyline
import random
import requests
import numpy as np
import pandas as pd
from glob import glob
import geopy.distance
from tqdm.notebook import tqdm
from html2image import Html2Image
import folium.plugins as plugins
from folium.plugins import MarkerCluster

base_folder = os.getcwd()
os.chdir(os.environ.get('cred_folder'))
import onemap_fun as om
os.chdir(base_folder)

# %% [markdown]
# ### OneMAP

# %%
latlong_filename = 'home_loc_tests.csv'

if glob(latlong_filename):
    print("Loading in local file that already exists!")
    final_df = pd.read_csv(latlong_filename)

else:
    df = pd.read_csv("data/local_df.csv")
    df['api_request'] = df['block'] + " " + df['street_name']
    df.api_request[0]

    sub_df = df.head(50)
    sub_df.shape

    onemap_results = list()
    for kw in tqdm(sub_df.api_request):
        onemap_results.append(om.loc_best_match(kw))

    sub_df['om_api'] = onemap_results

    expanded_om_results = sub_df['om_api'].apply(pd.Series)
    sub_df = pd.concat([sub_df, expanded_om_results], axis=1)
    final_df = sub_df[['town', 'flat', 'area', 'price', 'api_request', 
                       'SEARCHVAL', 'BLK_NO', 'ADDRESS', 'POSTAL', 'LATITUDE', 'LONGITUDE', 'score', 'search_keyword']]
    
    final_df.to_csv("data/home_loc_tests.csv", index=False)
# Out:
# Loading in local file that already exists!

# %%
final_df.shape
# Out:
# (50, 13)

# %% [markdown]
# #### Add mrt file

# %%
mrt_df = pd.read_csv("mrt_locations.csv")
mrt_df.head()
# Out:
#   code_string  code_num         BUILDING  POSTAL             X             Y  \
# 0          TE         1  WOODLANDS NORTH  737668  22699.991245  47770.394573
# 1          TE         2        WOODLANDS  737736  22949.919132  46417.522335
# 2          TE         3  WOODLANDS SOUTH  737741  23542.554570  45459.758822
# 3          NS         1      JURONG EAST  609690  17869.057052  35038.968870
# 4          NS         2      BUKIT BATOK  659958  18679.322319  36794.926021
#
#    LATITUDE   LONGITUDE
# 0  1.448292  103.785693
# 1  1.436058  103.787939
# 2  1.427396  103.793264
# 3  1.333153  103.742286
# 4  1.349033  103.749566

# %% [markdown]
# ### Functions for Mapping tasks

# %%
def table_select_from_pt(df: pd.DataFrame, loc_ll: tuple, select = True, select_radius = 1000) -> pd.DataFrame:
    """ Takes a Tuple Lat-Long input, a set of tables with Lat-Longs, and filters for include or exclude"""
    
    df_lat, df_long = df['LATITUDE'].tolist(), df['LONGITUDE'].tolist()
    df['dist'] = [geopy.distance.geodesic((float(i), float(j)), loc_ll).m for i,j in zip(df_lat, df_long)]
    if select: 
        selected_df = df[df['dist'] <= select_radius].reset_index(drop=True)
    else: 
        selected_df = df[df['dist'] > select_radius].reset_index(drop=True)
    
    return selected_df

# %%
def create_route(start_latlong: tuple, end_latlong: tuple, route_type: str = 'walk') -> list:
    """ Creates """
    
    # Route creation
    route_output = om.make_route_api(start_latlong, end_latlong, route_type=route_type)
    total_d = om.get_total_route_dist(route_output)

    # Processing walking route
    route_g = route_output.json().get('route_geometry')
    l = polyline.decode(route_g)
    routing = pd.concat([pd.Series(l), pd.Series(l)], axis=1)
    routing[1] = routing[1].shift(-1)
    route_list = [(i,j) for i,j in zip(routing[0], routing[1]) if j != None]
    
    return route_list, total_d

# %%
def generate_color(): 
    # Generate random values for red, green, and blue 
    r = random.randint(0, 255) 
    g = random.randint(0, 255) 
    b = random.randint(0, 255) 
    
    return f"rgb({r}, {g}, {b})"
 
print(generate_color())
# Out:
# rgb(195, 48, 2)

# %% [markdown]
# ### Simple Folium Map
# 1. This is a simple map with different location points

# %%
make_cluster = False
# Define coordinates of where we want to center our map
sg_coords = [final_df.loc[0]['LATITUDE'], final_df.loc[0]['LONGITUDE']]

# Create Map
hm = folium.Map(location = sg_coords, titles="OpenStreetMap", zoom_start=16)

if make_cluster:
    marker_cluster = MarkerCluster().add_to(hm)
    for i in range(final_df.shape[0]):
        folium.Marker([final_df.loc[i]['LATITUDE'], final_df.loc[i]['LONGITUDE']],
                          popup = final_df.loc[i]['ADDRESS'],
                          icon=folium.Icon(color="red"),
                         ).add_to(marker_cluster)
else:
    for i in range(final_df.shape[0]):
        folium.Marker([final_df.loc[i]['LATITUDE'], final_df.loc[i]['LONGITUDE']],
                          popup = final_df.loc[i]['ADDRESS'],
                          # icon=folium.Icon(color="red"),
                         ).add_to(hm)
        
# Add mrt locations
tmp = mrt_df.copy()
for i in range(tmp.shape[0]):
    folium.Marker([tmp.loc[i]['LATITUDE'], tmp.loc[i]['LONGITUDE']],
                  popup = tmp.loc[i]['BUILDING'],
                  icon=folium.Icon(color="green"),
                 ).add_to(hm)

hm
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_80d2ae924f407c0906c5a0e98c396567 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_80d2ae924f407c0906c5a0e98c396567&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_80d2ae924f407c0906c5a0e98c396567 = L.map(
#                 &quot;map_80d2ae924f407c0906c5a0e98c396567&quot;,
#                 {
#                     center: [1.36544495225352, 103.842715047475],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 16,
#                     zoomControl: true,
#                     preferCanvas: false,
#                     titles: &quot;OpenStreetMap&quot;,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_6a7ef6b84a2caaad8996a3d5400a1743 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_80d2ae924f407c0906c5a0e98c396567);
#
#
#             var marker_d43a2ae9e936a016f4003c8cdbdf4854 = L.marker(
#                 [1.36544495225352, 103.842715047475],
#                 {}
#             ).addTo(map_80d2ae924f407c0906c5a0e98c396567);
#
#
#         var popup_1496d416042e4465db86b8b53e89fc29 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_a14a468fe001968498179761d05360d1 = $(`&lt;div id=&quot;html_a14a468fe001968498179761d05360d1&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;208 ANG MO KIO AVENUE 1 ANG MO KIO 22 SINGAPORE 560208&lt;/div&gt;`)[0];
#                 popup_1496d416042e4465db86b8b53e89fc29.setContent(html_a14a468fe001968498179761d05360d1);
#
#
#
#         marker_d43a2ae9e936a016f4003c8cdbdf4854.bindPopup(popup_1496d416042e4465db86b8b53e89fc29)
#         ;
#
#
#
#
#             var marker_d9439839f9aae7b625003955457be10e = L.marker(
#                 [1.36556100435161, 103.845169497182],
#                 {}
#             ).addTo(map_80d2ae924f407c0906c5a0e98c396567);
#
#
#         var popup_5e3051ba1dec6d157838e5d89783d981 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_9f8e8b2e9dbd8e6ed775a4f4076224c1 = $(`&lt;div id=&quot;html_9f8e8b2e9dbd8e6ed775a4f4076224c1&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;307C ANG MO KIO AVENUE 1 TECK GHEE VISTA SINGAPORE 563307&lt;/div&gt;`)[0];
#                 popup_5e3051ba1dec6d157838e5d89783d981.setContent(html_9f8e8b2e9dbd8e6ed775a4f4076224c1);
#
#
#
#         marker_d9439839f9aae7b625003955457be10e.bindPopup(popup_5e3051ba1dec6d157838e5d89783d981)
#         ;
#
#
#
#
#             var marker_6683e54ce4c734f0342f6f9d09fe0828 = L.marker(
#                 [1.36511023350774, 103.847379037914],
#                 {}
#             ).addTo(map_80d2ae924f407c0906c5a0e98c396567);
#
#
#         var popup_4069692c065a36407138c0c69aaaa613 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_865d687f9e3255c639fb9399cd95b295 = $(`&lt;div id=&quot;html_865d687f9e3255c639fb9399cd95b295&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;319 ANG MO KIO AVENUE 1 PCF SPARKLETOTS PRESCHOOL @ TECK GHEE BLK 319 (KN) SINGAPORE 560319&lt;/div&gt;`)[0];
#                 popup_4069692c065a36407138c0c69aaaa613.setContent(html_865d687f9e3255c639fb9399cd95b295);
#
#
#
#         marker_6683e54ce4c734f0342f6f9d09fe0828.bindPopup(popup_4069692c065a36407138c0c69aaaa613)
#         ;
#
#
#
#
#             var marker_8d0dae4ec4994f34c6297a747ea5321d = L.marker(
#                 [1.36619678831054, 103.841505011903],
#                 {}
#             ).addTo(map_80d2ae924f407c0906c5a0e98c396567);
#
#
#         var popup_2e2add1a0c0ffa379f40a9a932fbec81 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_cf1abfc0a84dce1315e4bc6792685741 = $(`&lt;div id=&quot;html_cf1abfc0a84dce1315e4bc6792685741&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;216 ANG MO KIO AVENUE 1 ANG MO KIO 22 SINGAPORE 560216&lt;/div&gt;`)[0];
#                 popup_2e2add1a0c0ffa379f40a9a932fbec81.setContent(html_cf1abfc0a84dce1315e4bc6792685741);
#
#
#
#         marker_8d0dae4ec4994f34c6297a747ea5321d.bindPopup(popup_2e2add1a0c0ffa379f40a9a932fbec81)
#         ;
#
#
#
#
#             var marker_889150223ef31ef6c22a33712b6c2cf6 = L.marker(
#                 [1.37203235843331, 103.857625381508],
#                 {}
#             ).addTo(map_80d2ae924f407c0906c5a0e98c396567);
#
#
#         var popup_bd706f869fc5989e5f85626a1e0a9d93 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_aaa3858722c05d74e685dafb783f1536 = $(`&lt;div id=&quot;html_aaa3858722c05d74e685dafb783f1536&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;556 ANG MO KIO AVENUE 10 PCF SPARKLETOTS PRESCHOOL @ JALAN KAYU BLK 55

# %% [markdown]
# ### Search Boundaries
# 1. This creates a boundary around a specific location

# %%
# Create a separation between within radius and outside
# Note that this is an inefficient test of separation

# %%
# Identify location
selected_house = final_df.loc[0]
other_houses = final_df.loc[1:]
selected_house_latlong = (float(selected_house['LATITUDE']), float(selected_house['LONGITUDE']))

# This is the start of what my function does
houses_lat = other_houses['LATITUDE'].tolist()
houses_long = other_houses['LONGITUDE'].tolist()
other_houses['dist'] = [geopy.distance.geodesic((float(i), float(j)), selected_house_latlong).m for i,j in zip(houses_lat, houses_long)]
selection_radius = 1000

selected_homes = other_houses[other_houses['dist'] <= selection_radius].reset_index(drop=True)
unselected_homes = other_houses[other_houses['dist'] > selection_radius].reset_index(drop=True)

# %%
# Two checks to ensure that my function works! 
print(table_select_from_pt(other_houses, selected_house_latlong).equals(selected_homes))
print(table_select_from_pt(other_houses, selected_house_latlong, select=False).equals(unselected_homes))
# Out:
# True
# True

# %%
# Create Map with starting point
hm = folium.Map(location = selected_house_latlong, titles="OpenStreetMap", zoom_start=15)

# Houses within selected house
for i in range(selected_homes.shape[0]):
    folium.Marker([selected_homes.loc[i]['LATITUDE'], selected_homes.loc[i]['LONGITUDE']],
                      popup = selected_homes.loc[i]['ADDRESS'],
                      icon=folium.Icon(color="red"),
                     ).add_to(hm)

# Houses outside of selected house
for i in range(unselected_homes.shape[0]):
    folium.Marker([unselected_homes.loc[i]['LATITUDE'], unselected_homes.loc[i]['LONGITUDE']],
                      popup = unselected_homes.loc[i]['ADDRESS'],
                      icon=folium.Icon(color="blue"),
                     ).add_to(hm)

# Add selected marker
folium.Marker([selected_house['LATITUDE'], selected_house['LONGITUDE']],
              popup = selected_house['ADDRESS'],
              icon=folium.Icon(color="black"),
             ).add_to(hm)

# Add selected marker Circle
folium.Circle(
    location=[selected_house['LATITUDE'], selected_house['LONGITUDE']],
    radius=selection_radius,  # radius in meters
    color='blue',
    fill=True,
    fill_color='blue'
).add_to(hm)

# %%
table_select_from_pt(mrt_df, selected_house_latlong)
# Out:
#   code_string  code_num    BUILDING  POSTAL             X             Y  \
# 0          NS        16  ANG MO KIO  569811  29807.261147  39105.735995
#
#    LATITUDE   LONGITUDE       dist
# 0  1.369933  103.849558  908.96608

# %%
selected_mrt = table_select_from_pt(mrt_df, selected_house_latlong)
selected_mrt
# Out:
#   code_string  code_num    BUILDING  POSTAL             X             Y  \
# 0          NS        16  ANG MO KIO  569811  29807.261147  39105.735995
#
#    LATITUDE   LONGITUDE       dist
# 0  1.369933  103.849558  908.96608

# %%
# Select mrts that are near selected homes
tmp = selected_mrt.copy()
for i in range(tmp.shape[0]):
    folium.Marker([tmp.loc[i]['LATITUDE'], tmp.loc[i]['LONGITUDE']],
                  popup = tmp.loc[i]['BUILDING'],
                  icon=folium.Icon(color="green"),
                 ).add_to(hm)

hm
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_6bed17fddc6d7b68d1e5e7c7ff85a28a {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_6bed17fddc6d7b68d1e5e7c7ff85a28a&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_6bed17fddc6d7b68d1e5e7c7ff85a28a = L.map(
#                 &quot;map_6bed17fddc6d7b68d1e5e7c7ff85a28a&quot;,
#                 {
#                     center: [1.36544495225352, 103.842715047475],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 15,
#                     zoomControl: true,
#                     preferCanvas: false,
#                     titles: &quot;OpenStreetMap&quot;,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_01a70b9c5436dc360c90389fb5d5bab8 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_6bed17fddc6d7b68d1e5e7c7ff85a28a);
#
#
#             var marker_a650e571f86b192640d457374e2bc0c5 = L.marker(
#                 [1.36556100435161, 103.845169497182],
#                 {}
#             ).addTo(map_6bed17fddc6d7b68d1e5e7c7ff85a28a);
#
#
#             var icon_ce7b046e3a4ec5f99d1c248b0305c955 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_a650e571f86b192640d457374e2bc0c5.setIcon(icon_ce7b046e3a4ec5f99d1c248b0305c955);
#
#
#         var popup_885226f0b37e1faac36e8e75590e26dd = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_c4530681553b1e0b8c779a668fabc089 = $(`&lt;div id=&quot;html_c4530681553b1e0b8c779a668fabc089&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;307C ANG MO KIO AVENUE 1 TECK GHEE VISTA SINGAPORE 563307&lt;/div&gt;`)[0];
#                 popup_885226f0b37e1faac36e8e75590e26dd.setContent(html_c4530681553b1e0b8c779a668fabc089);
#
#
#
#         marker_a650e571f86b192640d457374e2bc0c5.bindPopup(popup_885226f0b37e1faac36e8e75590e26dd)
#         ;
#
#
#
#
#             var marker_105b4e876f07f717dccdce7cab610b98 = L.marker(
#                 [1.36511023350774, 103.847379037914],
#                 {}
#             ).addTo(map_6bed17fddc6d7b68d1e5e7c7ff85a28a);
#
#
#             var icon_e2a077ca9ef1a367da770be15c33a459 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_105b4e876f07f717dccdce7cab610b98.setIcon(icon_e2a077ca9ef1a367da770be15c33a459);
#
#
#         var popup_3f76f508ac9669456f342f34d9965329 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_3936fceee8d0fd3355eca5bc7d9d17f6 = $(`&lt;div id=&quot;html_3936fceee8d0fd3355eca5bc7d9d17f6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;319 ANG MO KIO AVENUE 1 PCF SPARKLETOTS PRESCHOOL @ TECK GHEE BLK 319 (KN) SINGAPORE 560319&lt;/div&gt;`)[0];
#                 popup_3f76f508ac9669456f342f34d9965329.setContent(html_3936fceee8d0fd3355eca5bc7d9d17f6);
#
#
#
#         marker_105b4e876f07f717dccdce7cab610b98.bindPopup(popup_3f76f508ac9669456f342f34d9965329)
#         ;
#
#
#
#
#             var marker_b1275c5cecaece5903ebcc2c65e0bc8a = L.marker(
#                 [1.36619678831054, 103.841505011903],
#                 {}
#             ).addTo(map_6bed17fddc6d7b68d1e5e7c7ff85a28a);
#
#
#             var icon_747410dc8744dd098552b24ed4e7678b = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_b1275c5cecaece5903ebcc2c65e0bc8a.setIcon(icon_747410dc8744dd098552b24ed4e7678b);
#
#
#         var popup_29588a42e9c8b49b5601c8981896719b = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_c6a7a115db08c1e26984f9e9256047c4 = $(`&lt;div id=&quot;html_c6a7a115db08c1e26984f9e9256047c4&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;216 ANG MO KIO AVENUE 1 ANG MO KIO 22 SINGAPORE 560216&lt;/div&gt;`)[0];
#                 popup_29588a42e9c8b49b5601c8981896719b.setContent(html_c6a7a115db08c1e26984f9e9256047c4);
#
#
#
#         marker_b1275c5cecaece5903ebcc2c65e0bc8a.bindPopup(popup_29588a42e9c8b49b5601c8981896719b)
#         ;
#
#
#
#
#             var marker_f4d03711aa137067b9c02d8f8a7c5f34 = L.marker(
#                 [1.36748702509964,

# %% [markdown]
# ### Routes
# #### Making API calls to get routes
# 1. Need to make API call for routes
# 1. Need more ways to make this code easier

# %%
target_route = float(unselected_homes.loc[0].LATITUDE), float(unselected_homes.loc[0].LONGITUDE)

# Driving
# route_output = om.make_route_api(selected_house_latlong, target_route)
# total_d = om.get_total_route_dist(route_output)

# Public transport route
# route_output = om.make_route_api(selected_house_latlong, target_route)
# total_d = om.get_total_route_dist(route_output)

# Walking route
route_output = om.make_route_api(selected_house_latlong, target_route, route_type='walk')
total_d = om.get_total_route_dist(route_output)

# %%
# Processing walking route
route_g = route_output.json().get('route_geometry')
l = polyline.decode(route_g)
routing = pd.concat([pd.Series(l), pd.Series(l)], axis=1)
routing[1] = routing[1].shift(-1)
route_list = [(i,j) for i,j in zip(routing[0], routing[1]) if j != None]

# %%
from folium.plugins import TagFilterButton
hm = folium.Map(location = selected_house_latlong, titles="OpenStreetMap", zoom_start=15)

# Plotting start marker
marker = folium.Marker(location=routing.loc[0][0])
marker.add_to(hm)

# Plotting end marker
marker = folium.Marker(location=routing.loc[routing.shape[0]-1][0])
marker.add_to(hm)

# Plotting route
for stops in route_list:
    line = folium.PolyLine(locations=[stops], 
                           tags=['Homes'], 
                           tooltip=f"Total Distance: {total_d :,.0f}m")
    line.add_to(hm)

# Create map and add the data with additional parameter tags as the segmentation
for i in range(selected_homes.shape[0]):
    folium.Marker([selected_homes.loc[i]['LATITUDE'], selected_homes.loc[i]['LONGITUDE']],
                  popup = selected_homes.loc[i]['ADDRESS'],
                  icon=folium.Icon(color="red"),
                  tags=['Homes']
                 ).add_to(hm)

# Create buttons
categories = ['Homes', "Offices"]
TagFilterButton(categories).add_to(hm)

hm
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_2c397dbc635bdc140cfdedeb72e995f2 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet-tag-filter-button/src/leaflet-tag-filter-button.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet-easybutton@2/src/easy-button.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet-tag-filter-button/src/leaflet-tag-filter-button.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet-easybutton@2/src/easy-button.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/css-ripple-effect@1.0.5/dist/ripple.min.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_2c397dbc635bdc140cfdedeb72e995f2&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_2c397dbc635bdc140cfdedeb72e995f2 = L.map(
#                 &quot;map_2c397dbc635bdc140cfdedeb72e995f2&quot;,
#                 {
#                     center: [1.36544495225352, 103.842715047475],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 15,
#                     zoomControl: true,
#                     preferCanvas: false,
#                     titles: &quot;OpenStreetMap&quot;,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_b9b7572c61337be790fbd230016ca6a5 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_2c397dbc635bdc140cfdedeb72e995f2);
#
#
#             var marker_438ba1825d107fb65a684aed682e1c5e = L.marker(
#                 [1.36544, 103.84272],
#                 {}
#             ).addTo(map_2c397dbc635bdc140cfdedeb72e995f2);
#
#
#             var marker_299198aadc1eef9124f0d43534662a33 = L.marker(
#                 [1.37206, 103.85762],
#                 {}
#             ).addTo(map_2c397dbc635bdc140cfdedeb72e995f2);
#
#
#             var poly_line_e978846e3afabdc235d57dffc6b94b3f = L.polyline(
#                 [[[1.36544, 103.84272], [1.36551, 103.84274]]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1.0, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_2c397dbc635bdc140cfdedeb72e995f2);
#
#
#             poly_line_e978846e3afabdc235d57dffc6b94b3f.bindTooltip(
#                 `&lt;div&gt;
#                      Total Distance: 2,284m
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var poly_line_96049e039483c4c084966d191b59e8df = L.polyline(
#                 [[[1.36551, 103.84274], [1.36575, 103.84282]]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1.0, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_2c397dbc635bdc140cfdedeb72e995f2);
#
#
#             poly_line_96049e039483c4c084966d191b59e8df.bindTooltip(
#                 `&lt;div&gt;
#                      Total Distance: 2,284m
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var poly_line_14c5b4f110f0587fd993764aae7ede6b = L.polyline(
#                 [[[1.36575, 103.84282], [1.36586, 103.84285]]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1.0, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_2c397dbc635bdc140cfdedeb72e995f2);
#
#
#             poly_line_14c5b4f110f0587fd993764aae7ede6b.bindTooltip(
#                 `&lt;div&gt;
#                      Total Distance: 2,284m
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var poly_line_6dab8bba6a7536da8b6c

# %% [markdown]
# ## Feature design 1
# - Put one location, makes API calls, and searches for MRTs around X,XXX metres

# %%
# Put location
keyword = "20 Clover Crescent"
select_radius = 1000

# Make OneMap API call
search_location_json = om.loc_best_match(keyword)
search_location_latlong = (search_location_json.get("LATITUDE"), search_location_json.get("LONGITUDE"))

# Do location filter
selected_mrt = table_select_from_pt(mrt_df, search_location_latlong, select_radius=select_radius)

## Create Map
# hm = folium.Map(location = search_location_latlong, titles="OpenStreetMap", zoom_start=15)
# hm = folium.Map(location = search_location_latlong, titles="Stamen Watercolor", zoom_start=15)
hm = folium.Map(location = search_location_latlong, titles="cartodbpositron", zoom_start=15)

# Add selected marker
folium.Marker(search_location_latlong,
              popup = search_location_json.get('ADDRESS'),
              tooltip = search_location_json.get('ADDRESS'),
              icon=plugins.BeautifyIcon(
                  icon="house",
                  icon_shape="circle",
                  text_color="white",
                  background_color='black',
                  border_color="black"),
             ).add_to(hm)

# Add selected marker Circle
folium.Circle(
    location=search_location_latlong,
    radius=select_radius,  # radius in meters
    color='blue',
    fill=True,
    fill_color='blue'
).add_to(hm)

group1 = folium.FeatureGroup(name='MRTs')

# MRTs within range of target home
tmp = selected_mrt.copy()
for i in range(tmp.shape[0]):
    
    # Set important marker & route info
    marker_info, marker_lat, marker_long = tmp.loc[i]['BUILDING'], tmp.loc[i]['LATITUDE'], tmp.loc[i]['LONGITUDE']

    # Add walking routes to MRT
    route_color = generate_color()
    route, total_d = create_route(search_location_latlong, (marker_lat, marker_long))
    tooltip_msg = f"{search_location_json.get('ADDRESS')} to {tmp.loc[i].BUILDING} <br>Total Distance: {total_d :,.0f}m"
    for stops in route:
        line = folium.PolyLine(locations=[stops],
                               color=route_color,
                               weight=5,
                               tooltip=tooltip_msg)
        line.add_to(group1)

    # MRT markers
    folium.Marker([marker_lat, marker_long],
                  popup = marker_info,
                  tooltip = tooltip_msg,
                  icon=plugins.BeautifyIcon(
                      icon="train-subway",
                      text_color="white",
                      icon_shape="circle",
                      background_color=route_color,
                      border_color=route_color),
                 ).add_to(group1)

group1.add_to(hm)

# Add layer control to switch between groups
folium.LayerControl().add_to(hm)

# Display the map
hm
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_4883d68288a6a2c16f20bc2c0f8a6221 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdn.jsdelivr.net/gh/marslan390/BeautifyMarker/leaflet-beautify-marker-icon.min.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/marslan390/BeautifyMarker/leaflet-beautify-marker-icon.min.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_4883d68288a6a2c16f20bc2c0f8a6221&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_4883d68288a6a2c16f20bc2c0f8a6221 = L.map(
#                 &quot;map_4883d68288a6a2c16f20bc2c0f8a6221&quot;,
#                 {
#                     center: [1.35001504573909, 103.84426624229],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 15,
#                     zoomControl: true,
#                     preferCanvas: false,
#                     titles: &quot;cartodbpositron&quot;,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_87d58da124a51fa66eaa0eca2d1111ca = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_4883d68288a6a2c16f20bc2c0f8a6221);
#
#
#             var marker_2154b54a4b223d60b0da37d5027885cf = L.marker(
#                 [1.35001504573909, 103.84426624229],
#                 {}
#             ).addTo(map_4883d68288a6a2c16f20bc2c0f8a6221);
#
#
#             var beautify_icon_8116fe89077ce2f7f86e4bfd0a60cea0 = new L.BeautifyIcon.icon(
#                 {&quot;backgroundColor&quot;: &quot;black&quot;, &quot;borderColor&quot;: &quot;black&quot;, &quot;borderWidth&quot;: 3, &quot;icon&quot;: &quot;house&quot;, &quot;iconShape&quot;: &quot;circle&quot;, &quot;innerIconStyle&quot;: &quot;&quot;, &quot;isAlphaNumericIcon&quot;: false, &quot;spin&quot;: false, &quot;textColor&quot;: &quot;white&quot;}
#             )
#             marker_2154b54a4b223d60b0da37d5027885cf.setIcon(beautify_icon_8116fe89077ce2f7f86e4bfd0a60cea0);
#
#
#         var popup_19e69aa118d1fffe30c8ef801d985784 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_0d6fa8016c1c1a4237d71d4374cdbbf3 = $(`&lt;div id=&quot;html_0d6fa8016c1c1a4237d71d4374cdbbf3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;20 CLOVER CRESCENT CLOVER PARK SINGAPORE 579194&lt;/div&gt;`)[0];
#                 popup_19e69aa118d1fffe30c8ef801d985784.setContent(html_0d6fa8016c1c1a4237d71d4374cdbbf3);
#
#
#
#         marker_2154b54a4b223d60b0da37d5027885cf.bindPopup(popup_19e69aa118d1fffe30c8ef801d985784)
#         ;
#
#
#
#
#             marker_2154b54a4b223d60b0da37d5027885cf.bindTooltip(
#                 `&lt;div&gt;
#                      20 CLOVER CRESCENT CLOVER PARK SINGAPORE 579194
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var circle_d563cb80eebbe865cf47985d22ad0140 = L.circle(
#                 [1.35001504573909, 103.84426624229],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 1000, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_4883d68288a6a2c16f20bc2c0f8a6221);
#
#
#             var feature_group_d78c4dcccbb27c9f2292ba68d4f613bd = L.featureGroup(
#                 {}
#             ).addTo(map_4883d68288a6a2c16f20bc2c0f8a6221);
#
#
#             var poly_line_cb54586ee819e19a1df08b4a7bb63979 = L.polyline(
#                 [[[1.35008, 103.84417], [1.35015, 103.84421]]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;rgb(101, 59, 0)&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;rgb(101, 59, 0)&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1.0, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 5}
#             ).addTo(feature_group_d78c4dcccbb27c9f2292ba68d4f613bd);
#
#
#             poly_line_cb54586ee819e19a1df08b4a7bb63979.bindTooltip(
#                 `&lt;div&gt;
#                      20 CLOVER CRESCENT CLOVER PARK SINGAPORE 579194 to BISHAN &lt;br&gt;Total Distance: 670m
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var poly_line_09df2f9a8265dc2f87102a5e6dfeecbe = L.polyline(
#                 [[[1.35015, 103.84421], [1.35017, 103

# %% [markdown]
# #### Create HTMLs from folium

# %%
filename = 'Test MRT Routes'
title_html = f'<h1 style="position:absolute;z-index:100000;left:40vw" >{filename}</h1>'
hm.get_root().html.add_child(folium.Element(title_html))
hm.save(f'{filename}.html')
time.sleep(1)

# %% [markdown]
# ### SpatialQuery
# 1. Need to see if I can create spatial queries and show them on folium
# 1. Makes sense that this requires backend processing!
#
# ### Regions
# Need to see if I can create regional overlays onto Folium maps
#
# ### Back Up Code

# %%
# Keep this code for future reference, but adding HTML tags to Folium maps seems rather not intuitive
# HTML template for the table
table_rows = ""
for (lat, lon, val) in zip(tmp['LATITUDE'].tolist(), tmp['LONGITUDE'].tolist(), tmp['BUILDING'].tolist()):
    table_rows += f"""
        <tr>
            <td style="border: 1px solid black; padding: 5px;">{lat:.4f}, {lon:.4f}</td>
            <td style="border: 1px solid black; padding: 5px;">{val}</td>
        </tr>
    """

html = f"""
<div style="position: fixed; bottom: 50px; right: 50px; width: 300px; height: auto; 
     background-color: white; border:2px solid grey; z-index:9999; font-size:14px;">
    <h4 style="margin-top: 10px; text-align:center;">Calculated Values</h4>
    <table style="width: 100%; border-collapse: collapse; margin: 10px;">
        <tr>
            <th style="border: 1px solid black; padding: 5px;">Location</th>
            <th style="border: 1px solid black; padding: 5px;">Value</th>
        </tr>
        {table_rows}
    </table>
</div>
"""

# # Add HTML element to the map
# from folium import IFrame
# iframe = IFrame(html, width=430, height=300)
# popup = folium.Popup(iframe, max_width=350)
folium.Marker(selected_house_latlong, icon=folium.DivIcon(
    icon_size=(100,20),
    icon_anchor=(5,5),
    html=f"""<div style="display:none;"></div>"""), 
              popup=popup).add_to(hm)

folium.map.Marker(location=search_location_latlong,
                  icon=folium.DivIcon(
                      icon_size=(100,20),
                      icon_anchor=(5,5),
                      html=html)
                 ).add_to(hm)
# Out:
# 1.31933570922513 103.861569454156 BOON KENG
# 1.33137949021367 103.869055656782 POTONG PASIR
# 1.3213011022832 103.871622627142 GEYLANG BAHRU
